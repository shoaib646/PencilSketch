# %%
from google.colab.patches import cv2_imshow  #main show of project
import cv2                                   #for reading our image

# %%
from google.colab import files      #''' uploading file on colag
uploaded = files.upload()                 #'''
# Out:
#      <input type="file" id="files-9a413e76-787f-4d3b-9543-ae6061361cd8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9a413e76-787f-4d3b-9543-ae6061361cd8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving upload.jpg to upload (1).jpg

# %%
img = cv2.imread('upload (1).jpg', 1)     #read image

# %%
cv2_imshow(img)                           #look our image
# Out:
# <PIL.Image.Image image mode=RGB size=204x259 at 0x7F95E0FCD7F0>

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  
cv2_imshow(gray)                          #conver image into grayscale
# Out:
# <PIL.Image.Image image mode=L size=204x259 at 0x7F95E0FDEE80>

# %%
img_invert = cv2.bitwise_not(gray)
cv2_imshow(img_invert)                          #modifying image
# Out:
# <PIL.Image.Image image mode=L size=204x259 at 0x7F95E0FDECF8>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)
cv2_imshow(img_smoothing)                       #modifying image more
# Out:
# <PIL.Image.Image image mode=L size=204x259 at 0x7F95E0FDE828>

# %%
def myfunc(x, y):    
    return cv2.divide(x, 255 - y, scale=256)          #function to create pencil skecth of our image

# %%
sketch = myfunc(gray, img_smoothing)
cv2_imshow(sketch)                                 #finally our pencil is ready
# Out:
# <PIL.Image.Image image mode=L size=204x259 at 0x7F95E0FCD630>
